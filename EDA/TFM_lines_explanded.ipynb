# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./opt/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.25.0)
# Requirement already satisfied: six>=1.5 in ./opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import re


# Ruta al archivo 
archivo = "/Users/severinodonate/Downloads/planet_osm_line_202505042033.csv"


# Leer el CSV con el separador correcto
df = pd.read_csv(archivo, sep=";", quotechar='"')

# Mostrar las primeras filas
df.head()
# Out:
#        osm_id access  addr:housename  addr:housenumber  addr:interpolation  \
# 0    73669102    NaN             NaN               NaN                 NaN
# 1    -6553940    NaN             NaN               NaN                 NaN
# 2  1213183116    NaN             NaN               NaN                 NaN
# 3  1213183085    NaN             NaN               NaN                 NaN
# 4  1213183086    NaN             NaN               NaN                 NaN
#
#    admin_level  aerialway  aeroway  amenity area  ... tunnel water  waterway  \
# 0          NaN        NaN      NaN      NaN  NaN  ...    NaN   NaN       NaN
# 1          NaN        NaN      NaN      NaN  NaN  ...    NaN   NaN       NaN
# 2          NaN        NaN      NaN      NaN  NaN  ...    NaN   NaN       NaN
# 3          NaN        NaN      NaN      NaN  NaN  ...    NaN   NaN       NaN
# 4          NaN        NaN      NaN      NaN  NaN  ...    NaN   NaN       NaN
#
#   wetland width  wood  z_order way_area  \
# 0     NaN   NaN   NaN        0      NaN
# 1     NaN   NaN   NaN        0      NaN
# 2     NaN   NaN   NaN        0      NaN
# 3     NaN   NaN   NaN        0      NaN
# 4     NaN   NaN   NaN        0      NaN
#
#                                                 tags  \
# 0              "geological"=>"palaeontological_site"
# 1  "name:en"=>"Pachacámac Monumental Archaeologic...
# 2                  "archaeological_site"=>"geoglyph"
# 3                  "archaeological_site"=>"geoglyph"
# 4                  "archaeological_site"=>"geoglyph"
#
#                                                  way
# 0  LINESTRING (-8489984.980579784 -1562464.423260...
# 1  LINESTRING (-8560383.19278652 -1372476.1649533...
# 2  LINESTRING (-7717552.9489016095 -7174193.14824...
# 3  LINESTRING (-7732935.899903656 -7170751.108254...
# 4  LINESTRING (-7732147.635457399 -7167582.551801...
#
# [5 rows x 70 columns]

# %%
import re

def parse_tags(tag_str):
    """
    Convierte un string de tags tipo 'key'=>"value" en un diccionario Python
    """
    if not isinstance(tag_str, str) or tag_str.strip() == "":
        return {}

    # Elimina comillas triples y extrae pares key=>value
    tag_pairs = re.findall(r'"([^"]+)"\s*=>\s*"([^"]*)"', tag_str)
    return {key: value for key, value in tag_pairs}

# %%
ejemplo = df['tags'].dropna().iloc[0]
print("Original:", ejemplo)
print("Parseado:", parse_tags(ejemplo))
# Out:
# Original: "geological"=>"palaeontological_site"
# Parseado: {'geological': 'palaeontological_site'}

# %%
df['tags_dict'] = df['tags'].apply(parse_tags)

# %%
# Aplicar la función a toda la columna
df['tags_dict'] = df['tags'].apply(parse_tags)

# Mostrar solo las columnas 'tags' y 'tags_dict' para comparar
df[['tags', 'tags_dict']].head()
# Out:
#                                                 tags  \
# 0              "geological"=>"palaeontological_site"
# 1  "name:en"=>"Pachacámac Monumental Archaeologic...
# 2                  "archaeological_site"=>"geoglyph"
# 3                  "archaeological_site"=>"geoglyph"
# 4                  "archaeological_site"=>"geoglyph"
#
#                                            tags_dict
# 0            {'geological': 'palaeontological_site'}
# 1  {'name:en': 'Pachacámac Monumental Archaeologi...
# 2                {'archaeological_site': 'geoglyph'}
# 3                {'archaeological_site': 'geoglyph'}
# 4                {'archaeological_site': 'geoglyph'}

# %%
# Expandir los diccionarios en columnas
tags_expandidos = pd.json_normalize(df['tags_dict'])

# Unir las nuevas columnas al dataframe original
df_expandido = pd.concat([df.drop(columns=['tags_dict']), tags_expandidos], axis=1)

# Mostrar las primeras filas del nuevo dataframe
df_expandido.head()
# Out:
#        osm_id access  addr:housename  addr:housenumber  addr:interpolation  \
# 0    73669102    NaN             NaN               NaN                 NaN
# 1    -6553940    NaN             NaN               NaN                 NaN
# 2  1213183116    NaN             NaN               NaN                 NaN
# 3  1213183085    NaN             NaN               NaN                 NaN
# 4  1213183086    NaN             NaN               NaN                 NaN
#
#    admin_level  aerialway  aeroway  amenity area  ... addr:state  dog  fax  \
# 0          NaN        NaN      NaN      NaN  NaN  ...        NaN  NaN  NaN
# 1          NaN        NaN      NaN      NaN  NaN  ...        NaN  NaN  NaN
# 2          NaN        NaN      NaN      NaN  NaN  ...        NaN  NaN  NaN
# 3          NaN        NaN      NaN      NaN  NaN  ...        NaN  NaN  NaN
# 4          NaN        NaN      NaN      NaN  NaN  ...        NaN  NaN  NaN
#
#   check_date ref:CR:SINAC  iucn_level  border_type protect_id  ref:nrhp  \
# 0        NaN          NaN         NaN          NaN        NaN       NaN
# 1        NaN          NaN         NaN          NaN        NaN       NaN
# 2        NaN          NaN         NaN          NaN        NaN       NaN
# 3        NaN          NaN         NaN          NaN        NaN       NaN
# 4        NaN          NaN         NaN          NaN        NaN       NaN
#
#   operator:wikipedia
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 388 columns]

# %%
print("Número de columnas:", df_expandido.shape[1])
# Out:
# Número de columnas: 388

# %%
df_expandido.columns.tolist()
# Out:
# ['osm_id',
#  'access',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:interpolation',
#  'admin_level',
#  'aerialway',
#  'aeroway',
#  'amenity',
#  'area',
#  'barrier',
#  'bicycle',
#  'brand',
#  'bridge',
#  'boundary',
#  'building',
#  'construction',
#  'covered',
#  'culvert',
#  'cutting',
#  'denomination',
#  'disused',
#  'embankment',
#  'foot',
#  'generator:source',
#  'harbour',
#  'highway',
#  'historic',
#  'horse',
#  'intermittent',
#  'junction',
#  'landuse',
#  'layer',
#  'leisure',
#  'lock',
#  'man_made',
#  'military',
#  'motorcar',
#  'name',
#  'natural',
#  'office',
#  'oneway',
#  'operator',
#  'place',
#  'population',
#  'power',
#  'power_source',
#  'public_transport',
#  'railway',
#  'ref',
#  'religion',
#  'route',
#  'service',
#  'shop',
#  'sport',
#  'surface',
#  'toll',
#  'tourism',
#  'tower:type',
#  'tracktype',
#  'tunnel',
#  'water',
#  'waterway',
#  'wetland',
#  'width',
#  'wood',
#  'z_order',
#  'way_area',
#  'tags',
#  'way',
#  'geological',
#  'name:en',
#  'name:fr',
#  'name:it',
#  'name:pt',
#  'website',
#  'alt_name',
#  'wikidata',
#  'wikipedia',
#  'wheelchair',
#  'protection_title',
#  'historic:civilization',
#  'archaeological_site',
#  'start_date',
#  'related_law',
#  'protect_class',
#  'protected_area',
#  'fence_type',
#  'short_name',
#  'opening_hours',
#  'operator:type',
#  'heritage',
#  'old_name',
#  'addr:city',
#  'ref:iphan',
#  'addr:street',
#  'addr:suburb',
#  'inscription',
#  'postal_code',
#  'motor_vehicle',
#  'bridge:structure',
#  'building:material',
#  'heritage:operator',
#  'abandoned:waterway',
#  'nswlpi:cadid',
#  'operator:wikidata',
#  'lanes',
#  'seasonal',
#  'maxspeed',
#  'cycleway:both',
#  'material',
#  'name:ar',
#  'fee',
#  'name:de',
#  'name:ru',
#  'ref:whc',
#  'name:el',
#  'name:pl',
#  'name:uk',
#  'int_name',
#  'name:es',
#  'name:he',
#  'name:hu',
#  'name:tr',
#  'description:en',
#  'description:he',
#  'description:hu',
#  'historic:period',
#  'name:en1',
#  'wall',
#  'name:be',
#  'whc:name',
#  'old_name:de',
#  'old_name:el',
#  'old_name:en',
#  'old_name:es',
#  'whc:website',
#  'old_name:grc',
#  'old_name:pnt',
#  'whc:criteria',
#  'whc:inscription_date',
#  'height',
#  'ele',
#  'ruins',
#  'historic:era',
#  'fortification_type',
#  'raä:id',
#  'raä:ref',
#  'two_sided',
#  'protection_status',
#  'field',
#  'name:grc',
#  'description',
#  'building:part',
#  'roof:colour',
#  'building:colour',
#  'wikimedia_commons',
#  'url',
#  'length',
#  'name:la',
#  'loc_name',
#  'url:mult',
#  'url:wikimapia',
#  'url:limes_pannonia',
#  'material:hu',
#  'location',
#  'ref:at:bda',
#  'year_of_construction',
#  'megalith_type',
#  'incline',
#  'related:wikidata',
#  'related:wikipedia',
#  'line',
#  'designation',
#  'historic:barrier',
#  'culture',
#  'lad:criteria',
#  'climbing',
#  'motorcycle',
#  'type',
#  'substance',
#  'survey:date',
#  'lit',
#  'segregated',
#  'artwork_type',
#  'collapsed:historic',
#  'nat_ref',
#  'name:bs',
#  'image',
#  'ref:kons',
#  'imagery_used',
#  'source_ref:url',
#  'heritage:website',
#  'kons:decision_number',
#  'kons:inscription_date',
#  'name:sr',
#  'name:ko',
#  'sac_scale',
#  'wall:type',
#  'fence',
#  'email',
#  'phone',
#  'addr:country',
#  'addr:postcode',
#  'addr:province',
#  'fence:material',
#  'boat',
#  'ship',
#  'motorboat',
#  'hgv',
#  'hov',
#  'psv',
#  'goods',
#  '4wd_only',
#  'mtb:scale',
#  'tourist_bus',
#  'agricultural',
#  'abandoned:railway',
#  'smoothness',
#  'trail_visibility',
#  'description:it',
#  'sidewalk',
#  'mtb:type',
#  'mtb:scale:uphill',
#  'bus',
#  'hazmat',
#  'bdouble',
#  'vehicle',
#  'kerb',
#  'nohousenumber',
#  'name:ca',
#  'ford',
#  'to',
#  'lwn',
#  'from',
#  'ascent',
#  'descent',
#  'lwn_ref',
#  'network',
#  'distance',
#  'duration',
#  'roundtrip',
#  'route_name',
#  'route_pref_color',
#  'bridge:name',
#  'via',
#  'lane_markings',
#  'ref:mhs',
#  'mhs:inscription_date',
#  'fortification',
#  'abandoned:track',
#  'ditch',
#  'disused:military',
#  'abandoned:military',
#  'razed:archaeological_site',
#  'epoch',
#  'razed:height',
#  'razed:barrier',
#  'end_date',
#  'heritage:ref',
#  'heritage:ref:gem',
#  'heritage:ref:lvr',
#  'heritage:ref:inspire',
#  'ref:fgkz',
#  'historic:waterway',
#  'name:nl',
#  'date',
#  'description:nl',
#  'name:etymology:wikidata',
#  'ref:rce',
#  'depth',
#  'oneway:bicycle',
#  'demolished:historic',
#  'embankment:type',
#  'castle_type',
#  'lanes:backward',
#  'lanes:forward',
#  'maxspeed:forward',
#  'maxspeed:backward',
#  'maxspeed:type',
#  'change:lanes',
#  'was:highway',
#  'construction_year',
#  'name:da',
#  'fence:colour',
#  'fence:height',
#  'colour',
#  'bollard',
#  'description:no',
#  'leaf_type',
#  'alt_name_1',
#  'alt_name_2',
#  'leaf_cycle',
#  'ref:FinnishNationalBoardOfAntiquities',
#  'gauge',
#  'electrified',
#  'name:th',
#  'mapillary',
#  'step_count',
#  'origin',
#  'name:gd',
#  'name:sco',
#  'status',
#  'resource',
#  'mineral',
#  'not_highway',
#  'conjectural',
#  'prow_ref',
#  'razed:railway',
#  'old_ref',
#  'usage',
#  'tracks',
#  'destination:backward',
#  'name:cy',
#  'highway_authority_ref',
#  'razed',
#  'listed_status',
#  'HE_ref',
#  'name:eu',
#  'name:fa',
#  'name:fi',
#  'name:ga',
#  'name:hr',
#  'name:id',
#  'name:ja',
#  'name:ka',
#  'name:lt',
#  'name:mt',
#  'name:nn',
#  'name:no',
#  'name:sh',
#  'name:sv',
#  'name:vi',
#  'name:zh',
#  'name:ceb',
#  'name:pnb',
#  'official_name',
#  'seamark:type',
#  'abandoned:highway',
#  'survey',
#  'ncn',
#  'ref:cadw',
#  'ref:IE:smr',
#  'capacity',
#  'ref:IE:nm',
#  'attraction',
#  'was:man_made',
#  'name:etymology',
#  'ref:cns',
#  'ref:ipa',
#  'ref:dgpc',
#  'site_status',
#  'heritage:since',
#  'heritage:website:sipa',
#  'heritage:website:arqueologia',
#  'bridge:name:br',
#  'tidal',
#  'name:br',
#  'protection_title:category',
#  'ref:bic',
#  'name:gl',
#  'alt_name:gl',
#  'pc:inscription_date',
#  'short_protection_title',
#  'legislation',
#  'ref:WDPA',
#  'ref:source',
#  'ruins:barrier',
#  'description:es',
#  'website:source',
#  'owner',
#  'ownership',
#  'protected',
#  'ref:hsmbc',
#  'hsmbc:criteria',
#  'maritime',
#  'boundary:type',
#  'operator:short',
#  'addr:state',
#  'dog',
#  'fax',
#  'check_date',
#  'ref:CR:SINAC',
#  'iucn_level',
#  'border_type',
#  'protect_id',
#  'ref:nrhp',
#  'operator:wikipedia']

# %%
# Guardar el dataframe en un nuevo archivo CSV
df_expandido.to_csv("/Users/severinodonate/Downloads/planet_osm_lines_expandido.csv", index=False, sep=';', quoting=1)

# %%
# Número total de filas
total_filas = len(df_expandido)

# Crear resumen de cobertura por variable
resumen = (
    df_expandido.notna()
    .sum()
    .reset_index()
    .rename(columns={"index": "variable", 0: "valores"})
)

# Calcular porcentaje de cobertura
resumen["porcentaje"] = (resumen["valores"] / total_filas * 100).round(2)

# Ordenar por porcentaje descendente
resumen = resumen.sort_values(by="porcentaje", ascending=False).reset_index(drop=True)

resumen
# Out:
#      variable  valores  porcentaje
# 0      osm_id     6949      100.00
# 1         way     6949      100.00
# 2     z_order     6949      100.00
# 3     barrier     2937       42.27
# 4    historic     2325       33.46
# ..        ...      ...         ...
# 383  way_area        0        0.00
# 384  building        0        0.00
# 385   wetland        0        0.00
# 386     water        0        0.00
# 387      wood        0        0.00
#
# [388 rows x 3 columns]

# %%
resumen.to_csv("/Users/severinodonate/Downloads/resumen_variables_lines.csv", index=False)
